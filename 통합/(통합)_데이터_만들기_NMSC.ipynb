# %% [markdown]
# <a href="https://colab.research.google.com/github/KorStats/skku/blob/main/%ED%86%B5%ED%95%A9/(%ED%86%B5%ED%95%A9)_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%A7%8C%EB%93%A4%EA%B8%B0_NMSC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'  'My Drive'   NSMC_train.csv	 ★졸업논문

# %%
import pandas as pd
df=pd.read_csv('/content/gdrive/MyDrive/NSMC_train.csv', encoding='utf-8-sig')

# %%
df['길이']=df['document'].apply(len)

# %%
df=df[df['길이']>50]

# %%
df['label'].value_counts()
# Out:
# label
# 0    17695
# 1    16860
# Name: count, dtype: int64

# %%
import pandas as pd
samples = {1 : 5000, 0 :4000 }
sampled_data = pd.DataFrame()
for category, n in samples.items():
    category_data = df[df['label'] == category]
    sampled_category_data = category_data.sample(n=n, random_state=42)
    sampled_data = pd.concat([sampled_data, sampled_category_data], ignore_index=True)
sampled_data.reset_index(drop=True, inplace=True)
sampled_data.head(3)
# Out:
#    Unnamed: 0       id                                           document  \
# 0       50955  9760313  디즈니가 전하고자 하는 메세지가 아름다웠고 감동이었다.그렇지만 약간은 진부한 느낌과...
# 1       76076  7930780  백일섭 아저씨 완전 짜증나게함..애도 아니고 먼 떼를 그렇게 쓰는지 참..안나왔으면...
# 2        5760  7250307  어릴적..내 입가에 미소를 번지게 한 영화..17년만에 다시 봐두 그들의 용기와 꿈...
#
#    label  길이
# 0      1  65
# 1      1  65
# 2      1  68

# %%
sampled_data['label'].value_counts()
# Out:
# label
# 1    5000
# 0    4000
# Name: count, dtype: int64

# %%
sampled_data.to_csv('NSMC_train_불균형_0.8.csv', encoding='utf-8-sig')

# %%
df=sampled_data

# %%
import pandas as pd
samples = {1 : 5000, 0 :2500 }
sampled_data = pd.DataFrame()
for category, n in samples.items():
    category_data = df[df['label'] == category]
    sampled_category_data = category_data.sample(n=n, random_state=42)
    sampled_data = pd.concat([sampled_data, sampled_category_data], ignore_index=True)
sampled_data.reset_index(drop=True, inplace=True)
sampled_data.head(3)
# Out:
#    Unnamed: 0       id                                           document  \
# 0       42817  9192449  진짜 웃김 웃다 너무웃겨서 눈물남ㅋㅋㅋㅋ근데 평점이 왜이러지? 네이버 평점도 믿을만...
# 1       33425  8046417  로그인 하게 만드는 댓글들이 보이는데 한글 제목과 포스터가 뭐가 문제가 되는지? 스...
# 2       91592  9810714  감독의 연출도 좋았지만 무엇보다 남주 스즈키 료헤이의 열연이 돋보인다!! 이보다 약...
#
#    label   길이
# 0      1   51
# 1      1  138
# 2      1   77

# %%
sampled_data['label'].value_counts()
# Out:
# label
# 1    5000
# 0    2500
# Name: count, dtype: int64

# %%
sampled_data.to_csv('NSMC_train_불균형_0.5.csv', encoding='utf-8-sig')

# %%
df=sampled_data

# %%
import pandas as pd
samples = {1 : 5000, 0 :1000 }
sampled_data = pd.DataFrame()
for category, n in samples.items():
    category_data = df[df['label'] == category]
    sampled_category_data = category_data.sample(n=n, random_state=42)
    sampled_data = pd.concat([sampled_data, sampled_category_data], ignore_index=True)
sampled_data.reset_index(drop=True, inplace=True)
sampled_data.head(3)
# Out:
#    Unnamed: 0        id                                           document  \
# 0       89597   8277442  오늘 CGV무비꼴라쥬에서 보고 왓습니다. 아직 감독님이 떠난걸 배우들이 크게 슬퍼하...
# 1       72091   9981062  잔잔하게 미소 지으며 볼 수 있는 영화...좋네여 오랫맛에 평점남겨봐여 상영관 없어...
# 2       46798  10137629  재미가 없다고 생각하는 사람들이 더러 있었다. 영화를 보며 배울 점도 많지만 꼭 그...
#
#    label   길이
# 0      1  105
# 1      1   57
# 2      1  138

# %%
sampled_data.to_csv('NSMC_train_불균형_0.2.csv', encoding='utf-8-sig')

# %%
df=sampled_data

# %%
import pandas as pd
samples = {1 : 5000, 0 :500 }
sampled_data = pd.DataFrame()
for category, n in samples.items():
    category_data = df[df['label'] == category]
    sampled_category_data = category_data.sample(n=n, random_state=42)
    sampled_data = pd.concat([sampled_data, sampled_category_data], ignore_index=True)
sampled_data.reset_index(drop=True, inplace=True)
sampled_data.head(3)
# Out:
#    Unnamed: 0        id                                           document  \
# 0       10178   6889887  밑의 평점들.. 도저히 이해가 안가네. 형식적인 기법이나 대단한 cg따위 없어도, ...
# 1       87773   9603294  솔직히 누구와 어떻게 아니면 혼자 어떤 기분으로 보느냐에따라 달라질수 있는 영화인것...
# 2       39076  10063815  비가 내릴때 느껴지는 쓸쓸한느낌같아서 마음한편이 고독해지는 느낌이 든다 해야되나 홀...
#
#    label  길이
# 0      1  98
# 1      1  67
# 2      1  77

# %%
sampled_data.to_csv('NSMC_train_불균형_0.1.csv', encoding='utf-8-sig')

# %%
df=sampled_data

# %%
import pandas as pd
samples = {1 : 5000, 0 :100 }
sampled_data = pd.DataFrame()
for category, n in samples.items():
    category_data = df[df['label'] == category]
    sampled_category_data = category_data.sample(n=n, random_state=42)
    sampled_data = pd.concat([sampled_data, sampled_category_data], ignore_index=True)
sampled_data.reset_index(drop=True, inplace=True)
sampled_data.head(3)
# Out:
#    Unnamed: 0        id                                           document  \
# 0        9145   8954569  결말 되게맘에든다 남자가 여자에게 끝내 못닿고 여자와 같은 길을 것이라는 결말......
# 1       33435   7560803  배경,배우,연기,스토리 모두 대단하다! 막장스런 전개, 어쩌면 이것이 여과없는 우리...
# 2       21442  10251211  "우주 영화임에도 감동을 억지로 짜낸 우리나라 영화보다 감동과 전율이 엄청난 영화다...
#
#    label   길이
# 0      1   60
# 1      1   68
# 2      1  140

# %%
sampled_data.to_csv('NSMC_train_불균형_0.02.csv', encoding='utf-8-sig')
